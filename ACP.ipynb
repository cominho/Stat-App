# %%
import pandas as pd 
import numpy
import matplotlib.pyplot as plt
import scipy.stats
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import sklearn.metrics

# %%
## réalisation de l'ACP

# %%
enedis = pd.read_csv("/Users/jeremiedarracq/Stat-app/enedis.csv",sep=";")

# %%
## On récupère la date
enedis["date"]=enedis["Horodate"].apply(lambda x : x[0:10])
## On récupère les données de température régionales
meteo_reg =pd.read_csv("/Users/jeremiedarracq/Stat-app/temperature_reg.csv",sep=";")
## On récupères les indices socios régionaux
socio=pd.read_csv("/Users/jeremiedarracq/Stat-app//data.csv",sep=";",header=2)
socio["Code"]=socio["Code"].astype("str")
socio.drop(socio[ (socio['Code'] == "1") | (socio['Code'] == "2") | (socio['Code'] == "3") | (socio['Code'] == "4") | (socio['Code'] == "6")].index, inplace=True)
socio["Code"]=pd.to_numeric(socio["Code"])
## On fusionne indice socio et consommations électrique 
enedis_socio=pd.merge(enedis,socio,how='left',left_on="Code région",right_on="Code")
enedis_socio
meteo_reg
enedis
# Out:
#                           Horodate                Région  Code région  \
# 0        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# 1        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# 2        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# 3        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# 4        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# ...                            ...                   ...          ...
# 4874994  2022-06-19T18:30:00+02:00              Bretagne           53
# 4874995  2022-06-19T18:30:00+02:00              Bretagne           53
# 4874996  2022-06-19T18:30:00+02:00              Bretagne           53
# 4874997  2022-06-19T18:30:00+02:00              Bretagne           53
# 4874998  2022-06-19T18:30:00+02:00              Bretagne           53
#
#                          Profil Plage de puissance souscrite  \
# 0          ENT3 (+ ENT4 + ENT5)          P0: Total <= 36 kVA
# 1               PRO1 (+ PRO1WE)               P4: ]9-12] kVA
# 2               PRO1 (+ PRO1WE)              P8: ]24-30] kVA
# 3        PRO2 (+ PRO2WE + PRO6)                P3: ]6-9] kVA
# 4                          PRO5                P1: ]0-3] kVA
# ...                         ...                          ...
# 4874994         PRO1 (+ PRO1WE)              P7: ]18-24] kVA
# 4874995         PRO1 (+ PRO1WE)              P9: ]30-36] kVA
# 4874996  PRO2 (+ PRO2WE + PRO6)              P6: ]15-18] kVA
# 4874997                    PRO3              P5: ]12-15] kVA
# 4874998                    PRO4              P6: ]15-18] kVA
#
#          Nb points soutirage  Total énergie soutirée (Wh)  \
# 0                       1376                    2095739.0
# 1                      52691                   12376840.0
# 2                       8350                    6545703.0
# 3                      19759                    7072016.0
# 4                      55645                   18921676.0
# ...                      ...                          ...
# 4874994                 5742                    4196121.0
# 4874995                12137                   13049064.0
# 4874996                11245                   10172680.0
# 4874997                   31                          NaN
# 4874998                 1674                     709912.0
#
#          Courbe Moyenne n°1 (Wh) Indice représentativité Courbe n°1 (%)  \
# 0                         2084.0                                     48
# 1                          443.0                                      8
# 2                         1012.0                                     10
# 3                          693.0                                     13
# 4                          428.0                                     16
# ...                          ...                                    ...
# 4874994                    715.0                                     13
# 4874995                   1082.0                                     14
# 4874996                   1113.0                                     14
# 4874997                      NaN                                      S
# 4874998                    323.0                                     19
#
#          Courbe Moyenne n°2 (Wh) Indice représentativité Courbe n°2 (%)  \
# 0                         1368.0                                     48
# 1                          202.0                                      8
# 2                          474.0                                     11
# 3                          466.0                                     13
# 4                          239.0                                     16
# ...                          ...                                    ...
# 4874994                    497.0                                     14
# 4874995                    597.0                                     15
# 4874996                    801.0                                     14
# 4874997                      NaN                                      S
# 4874998                    219.0                                     19
#
#          Courbe Moyenne n°1 + n°2 (Wh)  \
# 0                               1727.0
# 1                                322.0
# 2                                742.0
# 3                                579.0
# 4                                334.0
# ...                                ...
# 4874994                          603.0
# 4874995                          834.0
# 4874996                          956.0
# 4874997                            NaN
# 4874998                          342.0
#
#         Indice représentativité Courbe n°1 + n°2 (%)  Jour max du mois (0/1)  \
# 0                                                 97                       0
# 1                                                 16                       0
# 2                                                 22                       0
# 3                                                 26                       0
# 4                                                 33                       0
# ...                                              ...                     ...
# 4874994                                           27                       0
# 4874995                                           29                       0
# 4874996                                           29                       0
# 4874997                                            S                       0
# 4874998                                           39                       0
#
#          Semaine max du mois (0/1)        date
# 0                                1  2022-09-30
# 1                                1  2022-09-30
# 2                                1  2022-09-30
# 3                                1  2022-09-30
# 4                                1  2022-09-30
# ...                            ...         ...
# 4874994                          1  2022-06-19
# 4874995                          1  2022-06-19
# 4874996                          1  2022-06-19
# 4874997                          1  2022-06-19
# 4874998                          1  2022-06-19
#
# [4874999 rows x 16 columns]

# %%
enedis_final=pd.merge(enedis_socio,meteo_reg,how='left',left_on=["date","Code région"],right_on=["date","code_insee_region"])
enedis_final
# Out:
#                           Horodate                Région  Code région  \
# 0        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# 1        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# 2        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# 3        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# 4        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes           84
# ...                            ...                   ...          ...
# 4874994  2022-06-19T18:30:00+02:00              Bretagne           53
# 4874995  2022-06-19T18:30:00+02:00              Bretagne           53
# 4874996  2022-06-19T18:30:00+02:00              Bretagne           53
# 4874997  2022-06-19T18:30:00+02:00              Bretagne           53
# 4874998  2022-06-19T18:30:00+02:00              Bretagne           53
#
#                          Profil Plage de puissance souscrite  \
# 0          ENT3 (+ ENT4 + ENT5)          P0: Total <= 36 kVA
# 1               PRO1 (+ PRO1WE)               P4: ]9-12] kVA
# 2               PRO1 (+ PRO1WE)              P8: ]24-30] kVA
# 3        PRO2 (+ PRO2WE + PRO6)                P3: ]6-9] kVA
# 4                          PRO5                P1: ]0-3] kVA
# ...                         ...                          ...
# 4874994         PRO1 (+ PRO1WE)              P7: ]18-24] kVA
# 4874995         PRO1 (+ PRO1WE)              P9: ]30-36] kVA
# 4874996  PRO2 (+ PRO2WE + PRO6)              P6: ]15-18] kVA
# 4874997                    PRO3              P5: ]12-15] kVA
# 4874998                    PRO4              P6: ]15-18] kVA
#
#          Nb points soutirage  Total énergie soutirée (Wh)  \
# 0                       1376                    2095739.0
# 1                      52691                   12376840.0
# 2                       8350                    6545703.0
# 3                      19759                    7072016.0
# 4                      55645                   18921676.0
# ...                      ...                          ...
# 4874994                 5742                    4196121.0
# 4874995                12137                   13049064.0
# 4874996                11245                   10172680.0
# 4874997                   31                          NaN
# 4874998                 1674                     709912.0
#
#          Courbe Moyenne n°1 (Wh) Indice représentativité Courbe n°1 (%)  \
# 0                         2084.0                                     48
# 1                          443.0                                      8
# 2                         1012.0                                     10
# 3                          693.0                                     13
# 4                          428.0                                     16
# ...                          ...                                    ...
# 4874994                    715.0                                     13
# 4874995                   1082.0                                     14
# 4874996                   1113.0                                     14
# 4874997                      NaN                                      S
# 4874998                    323.0                                     19
#
#          Courbe Moyenne n°2 (Wh)  ... Part des 45-59 ans 2018  \
# 0                         1368.0  ...                    19.8
# 1                          202.0  ...                    19.8
# 2                          474.0  ...                    19.8
# 3                          466.0  ...                    19.8
# 4                          239.0  ...                    19.8
# ...                          ...  ...                     ...
# 4874994                    497.0  ...                    20.1
# 4874995                    597.0  ...                    20.1
# 4874996                    801.0  ...                    20.1
# 4874997                      NaN  ...                    20.1
# 4874998                    219.0  ...                    20.1
#
#          Part des 60-74 ans 2018 Part des 75 ans et plus 2018  \
# 0                           16.2                          9.4
# 1                           16.2                          9.4
# 2                           16.2                          9.4
# 3                           16.2                          9.4
# 4                           16.2                          9.4
# ...                          ...                          ...
# 4874994                     18.1                         10.5
# 4874995                     18.1                         10.5
# 4874996                     18.1                         10.5
# 4874997                     18.1                         10.5
# 4874998                     18.1                         10.5
#
#          Taux de chômage des 15 ans et plus (RP) 2018                      id  \
# 0                                                11.4  2022-09-30T00:00:00-84
# 1                                                11.4  2022-09-30T00:00:00-84
# 2                                                11.4  2022-09-30T00:00:00-84
# 3                                                11.4  2022-09-30T00:00:00-84
# 4                                                11.4  2022-09-30T00:00:00-84
# ...                                               ...                     ...
# 4874994                                          11.4  2022-06-19T00:00:00-53
# 4874995                                          11.4  2022-06-19T00:00:00-53
# 4874996                                          11.4  2022-06-19T00:00:00-53
# 4874997                                          11.4  2022-06-19T00:00:00-53
# 4874998                                          11.4  2022-06-19T00:00:00-53
#
#         code_insee_region                region   tmin   tmax   tmoy
# 0                    84.0  Auvergne-Rhône-Alpes   6.21  14.74  10.47
# 1                    84.0  Auvergne-Rhône-Alpes   6.21  14.74  10.47
# 2                    84.0  Auvergne-Rhône-Alpes   6.21  14.74  10.47
# 3                    84.0  Auvergne-Rhône-Alpes   6.21  14.74  10.47
# 4                    84.0  Auvergne-Rhône-Alpes   6.21  14.74  10.47
# ...                   ...                   ...    ...    ...    ...
# 4874994              53.0              Bretagne  12.80  18.40  15.60
# 4874995              53.0              Bretagne  12.80  18.40  15.60
# 4874996              53.0              Bretagne  12.80  18.40  15.60
# 4874997              53.0              Bretagne  12.80  18.40  15.60
# 4874998              53.0              Bretagne  12.80  18.40  15.60
#
# [4874999 rows x 41 columns]

# %%
enedis_stat_desc = enedis_final.drop(columns=["Code région","Plage de puissance souscrite","Courbe Moyenne n°1 (Wh)","Indice représentativité Courbe n°1 (%)","Courbe Moyenne n°2 (Wh)","code_insee_region","id","Indice représentativité Courbe n°2 (%)","Courbe Moyenne n°1 + n°2 (Wh)","Indice représentativité Courbe n°1 + n°2 (%)","Jour max du mois (0/1)","Semaine max du mois (0/1)","date","Code","Libellé","region","tmin","tmax","Population au dernier recensement 2018",'Part des "agriculteurs exploitants" dans la population 2018','Part des "employés" dans la population 2018',"Part des 30-44 ans 2018","Part des 45-59 ans 2018","Part des 60-74 ans 2018"])
enedis_stat_desc
# Out:
#                           Horodate                Région  \
# 0        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes
# 1        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes
# 2        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes
# 3        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes
# 4        2022-09-30T23:30:00+02:00  Auvergne-Rhône-Alpes
# ...                            ...                   ...
# 4874994  2022-06-19T18:30:00+02:00              Bretagne
# 4874995  2022-06-19T18:30:00+02:00              Bretagne
# 4874996  2022-06-19T18:30:00+02:00              Bretagne
# 4874997  2022-06-19T18:30:00+02:00              Bretagne
# 4874998  2022-06-19T18:30:00+02:00              Bretagne
#
#                          Profil  Nb points soutirage  \
# 0          ENT3 (+ ENT4 + ENT5)                 1376
# 1               PRO1 (+ PRO1WE)                52691
# 2               PRO1 (+ PRO1WE)                 8350
# 3        PRO2 (+ PRO2WE + PRO6)                19759
# 4                          PRO5                55645
# ...                         ...                  ...
# 4874994         PRO1 (+ PRO1WE)                 5742
# 4874995         PRO1 (+ PRO1WE)                12137
# 4874996  PRO2 (+ PRO2WE + PRO6)                11245
# 4874997                    PRO3                   31
# 4874998                    PRO4                 1674
#
#          Total énergie soutirée (Wh)  \
# 0                          2095739.0
# 1                         12376840.0
# 2                          6545703.0
# 3                          7072016.0
# 4                         18921676.0
# ...                              ...
# 4874994                    4196121.0
# 4874995                   13049064.0
# 4874996                   10172680.0
# 4874997                          NaN
# 4874998                     709912.0
#
#          Part des "artisans, commerçants, chefs d'entreprise" dans la population 2018  \
# 0                                                      3.9
# 1                                                      3.9
# 2                                                      3.9
# 3                                                      3.9
# 4                                                      3.9
# ...                                                    ...
# 4874994                                                3.5
# 4874995                                                3.5
# 4874996                                                3.5
# 4874997                                                3.5
# 4874998                                                3.5
#
#          Part des "ouvriers" dans la population 2018  \
# 0                                               12.4
# 1                                               12.4
# 2                                               12.4
# 3                                               12.4
# 4                                               12.4
# ...                                              ...
# 4874994                                         13.0
# 4874995                                         13.0
# 4874996                                         13.0
# 4874997                                         13.0
# 4874998                                         13.0
#
#          Part des "retraités" dans la population 2018  \
# 0                                                27.0
# 1                                                27.0
# 2                                                27.0
# 3                                                27.0
# 4                                                27.0
# ...                                               ...
# 4874994                                          31.2
# 4874995                                          31.2
# 4874996                                          31.2
# 4874997                                          31.2
# 4874998                                          31.2
#
#          Part des "professions intermédiaires" dans la population 2018  \
# 0                                                     15.2
# 1                                                     15.2
# 2                                                     15.2
# 3                                                     15.2
# 4                                                     15.2
# ...                                                    ...
# 4874994                                               13.7
# 4874995                                               13.7
# 4874996                                               13.7
# 4874997                                               13.7
# 4874998                                               13.7
#
#          Part des "autres sans activité professionnelle" dans la population 2018  \
# 0                                                     15.7
# 1                                                     15.7
# 2                                                     15.7
# 3                                                     15.7
# 4                                                     15.7
# ...                                                    ...
# 4874994                                               14.7
# 4874995                                               14.7
# 4874996                                               14.7
# 4874997                                               14.7
# 4874998                                               14.7
#
#          Part des "autres sans activité professionnelle" dans la population 2018.1  \
# 0                                                     18.3
# 1                                                     18.3
# 2                                                     18.3
# 3                                                     18.3
# 4                                                     18.3
# ...                                                    ...
# 4874994                                               16.2
# 4874995                                               16.2
# 4874996                                               16.2
# 4874997                                               16.2
# 4874998                                               16.2
#
#          Part des "cadres et professions intellectuelles supérieures" dans la population 2018  \
# 0                                                      9.4
# 1                                                      9.4
# 2                                                      9.4
# 3                                                      9.4
# 4                                                      9.4
# ...                                                    ...
# 4874994                                                7.6
# 4874995                                                7.6
# 4874996                                                7.6
# 4874997                                                7.6
# 4874998                                                7.6
#
#          Médiane du revenu disponible par UC 2018  Part des 15-29 ans 2018  \
# 0                                         22480.0                     17.6
# 1                                         22480.0                     17.6
# 2                                         22480.0                     17.6
# 3                                         22480.0                     17.6
# 4                                         22480.0                     17.6
# ...                                           ...                      ...
# 4874994                                   21750.0                     16.4
# 4874995                                   21750.0                     16.4
# 4874996                                   21750.0                     16.4
# 4874997                                   21750.0                     16.4
# 4874998                                   21750.0                     16.4
#
#          Part des 75 ans et plus 2018  \
# 0                                 9.4
# 1                                 9.4
# 2                                 9.4
# 3                                 9.4
# 4                                 9.4
# ...                               ...
# 4874994                          10.5
# 4874995                          10.5
# 4874996                          10.5
# 4874997                          10.5
# 4874998                          10.5
#
#          Taux de chômage des 15 ans et plus (RP) 2018   tmoy
# 0                                                11.4  10.47
# 1                                                11.4  10.47
# 2                                                11.4  10.47
# 3                                                11.4  10.47
# 4                                                11.4  10.47
# ...                                               ...    ...
# 4874994                                          11.4  15.60
# 4874995                                          11.4  15.60
# 4874996                                          11.4  15.60
# 4874997                                          11.4  15.60
# 4874998                                          11.4  15.60
#
# [4874999 rows x 17 columns]

# %%
## Modèle de Régression linéaire

## On se concentre sur l'IDF 

enedis_reg = enedis_stat_desc.drop(columns = ["Horodate", "Région","Profil","Total énergie soutirée (Wh)"])
enedis_reg["Consommation d'énergie moyenne"] = enedis_final["Total énergie soutirée (Wh)"]/enedis_final["Nb points soutirage"]

## régression 
enedi
lmodellineaire = LinearRegression()
lmodellineaire.fit(enedis_reg["Médiane du revenu disponible par UC 2018"],enedis_reg["Consommation d'énergie moyenne"])

matrice_corr = enedis_reg.corr()

sns.heatmap(data=matrice_corr, annot=True)

## On enlèvre les colonnes non numériques

##plt.plot(enedis_idf_Profil.Horodate,(enedis_idf_Profil["Total énergie soutirée (Wh)"])/1000)

# %%
##enedis_idf_Profil
